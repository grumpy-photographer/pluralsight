# %%
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace = go.Heatmap(z=[[8, 64], [3, 37]])

# %%
data = [trace]

offline.iplot(data)
# Out:
# <div>                            <div id="c5dd5805-d899-4dd6-a990-ea84d9ed57be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5dd5805-d899-4dd6-a990-ea84d9ed57be")) {                    Plotly.newPlot(                        "c5dd5805-d899-4dd6-a990-ea84d9ed57be",                        [{"type": "heatmap", "z": [[8, 64], [3, 37]]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, " ...

# %%
import pandas as pd

housing_data = pd.read_csv("data/housing.csv")

housing_data.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15496    -117.25     33.12                 8.0       8552.0          1437.0
# 19639    -120.80     37.55                18.0       1802.0           335.0
# 18343    -122.15     37.43                47.0       2600.0           490.0
# 7293     -118.23     33.98                35.0       1366.0           496.0
# 6617     -118.11     34.17                46.0       2837.0           592.0
# 2101     -119.76     36.74                52.0       2137.0           448.0
# 20149    -119.12     34.38                28.0       7200.0          1281.0
# 20634    -121.56     39.27                28.0       2332.0           395.0
# 7056     -118.03     33.92                35.0       2108.0           405.0
# 7518     -118.25     33.91                35.0       1479.0           272.0
#
#        population  households  median_income  median_house_value  \
# 15496      3335.0      1323.0         5.3110            255800.0
# 19639      1110.0       329.0         3.1641             96300.0
# 18343      1149.0       465.0         5.0203            476300.0
# 7293       2160.0       497.0         2.2059            150000.0
# 6617       1453.0       549.0         3.1115            234600.0
# 2101       1194.0       444.0         1.3029             69100.0
# 20149      3793.0      1238.0         4.0750            237900.0
# 20634      1041.0       344.0         3.7125            116800.0
# 7056       1243.0       394.0         3.6731            167000.0
# 7518        963.0       292.0         3.4917            109500.0
#
#       ocean_proximity
# 15496      NEAR OCEAN
# 19639          INLAND
# 18343        NEAR BAY
# 7293        <1H OCEAN
# 6617           INLAND
# 2101           INLAND
# 20149       <1H OCEAN
# 20634          INLAND
# 7056        <1H OCEAN
# 7518        <1H OCEAN

# %%
housing_data.shape
# Out:
# (20640, 10)

# %%
housing_data = housing_data.sample(frac=0.1).reset_index(drop=True)
housing_data.shape
# Out:
# (2064, 10)

# %%
median = housing_data["median_house_value"].median()

median
# Out:
# 180050.0

# %%
housing_data["above_median"] = (housing_data["median_house_value"] - median) > 0

housing_data.sample(5)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 377     -117.05     33.05                 6.0       7916.0          1293.0
# 1621    -119.24     35.77                28.0       1737.0           521.0
# 1149    -122.17     37.45                35.0       1025.0           242.0
# 1380    -117.58     33.89                14.0       1731.0           404.0
# 789     -123.22     39.28                16.0       5569.0          1106.0
#
#       population  households  median_income  median_house_value  \
# 377       2741.0      1204.0         5.6436            278600.0
# 1621      1764.0       514.0         1.7813             67800.0
# 1149       388.0       232.0         5.1995            500001.0
# 1380      1269.0       351.0         2.3654            107900.0
# 789       3148.0      1088.0         3.1455            142900.0
#
#      ocean_proximity  above_median
# 377        <1H OCEAN          True
# 1621          INLAND         False
# 1149        NEAR BAY          True
# 1380          INLAND         False
# 789        <1H OCEAN         False

# %%
trace = go.Heatmap(
    z=housing_data["median_house_value"],
    x=housing_data["ocean_proximity"],
    y=housing_data["above_median"],
    colorscale="Jet",
    reversescale=True,
)

# %%
data = [trace]
offline.iplot(data)
# Out:
# <div>                            <div id="74d2686e-d741-4366-89ad-ee986d7021b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74d2686e-d741-4366-89ad-ee986d7021b0")) {                    Plotly.newPlot(                        "74d2686e-d741-4366-89ad-ee986d7021b0",                        [{"colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]], "reversescale": true, "type": "heatmap", "x": ["<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR BAY", "NEAR OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "NEAR BAY", "NEAR BAY", "NEAR BAY", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "INLAND", "ISLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "NEAR BAY", "INLAND", "NEAR OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "INLAND", "INLAND", "INLAND", "NEAR BAY", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "INLAND", "INLAND", "NEAR BAY", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "NEAR BAY", "INLAND", "NEAR BAY", "INLAND", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "INLAND", "INLAND", "INLAND", "INLAND", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "NEAR BAY" ...
