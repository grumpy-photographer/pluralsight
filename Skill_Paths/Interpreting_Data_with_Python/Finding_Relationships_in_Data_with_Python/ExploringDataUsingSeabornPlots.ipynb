# %%
import datetime
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips_data = pd.read_csv("datasets/tips.csv")

tips_data.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 48        28.55  2.05    Male     No   Sun  Dinner     3
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 115       17.31  3.50  Female     No   Sun  Dinner     2
# 130       19.08  1.50    Male     No  Thur   Lunch     2
# 228       13.28  2.72    Male     No   Sat  Dinner     2

# %%
tips_data.shape
# Out:
# (244, 7)

# %%
 tips_data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_data.groupby(by="time").mean()
# Out:
#         total_bill       tip      size
# time
# Dinner   20.797159  3.102670  2.630682
# Lunch    17.168676  2.728088  2.411765

# %%
plt.figure(figsize=(12, 8))

sns.barplot(x="time", y="total_bill", data= tips_data)

plt.title("Bill and Tips")
plt.xticks(rotation=90)

plt.show();

# %%
mean = tips_data['tip'].mean()

mean
# Out:
# 2.99827868852459

# %%
tips_data["above average"] = (tips_data['tip'] - mean) > 0

tips_data[["tip", "above average"]].head()
# Out:
#     tip  above average
# 0  1.01          False
# 1  1.66          False
# 2  3.50           True
# 3  3.31           True
# 4  3.61           True

# %%
plt.figure(figsize=(12, 8))

sns.countplot('time', hue='above average', data=tips_data, order=tips_data['time'].value_counts().index)

plt.title("Bill and Tips")

plt.show();
# Out:
# C:\Users\natha\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 8))

sns.countplot("time", hue="sex", data=tips_data, order=tips_data["time"].value_counts().index)

plt.title("Bill and Tips")

plt.show();
# Out:
# C:\Users\natha\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 8))

sns.boxplot(x="sex", y="total_bill", data=tips_data, palette="nipy_spectral")

plt.title("Bill and Tips")

plt.show();

# %%
plt.figure(figsize=(12, 8))

sns.boxplot(x="size", y="total_bill", data=tips_data, palette="nipy_spectral")

plt.title("Bill and Tips")

plt.show();

# %%
sns.catplot(x="size", y="total_bill", hue="time", data=tips_data, kind="bar", height=6, aspect = 2, palette="CMRmap")

plt.title("Bill and Tips")

plt.show();

# %%
plt.figure(figsize=(12, 8))

sns.stripplot(x="size", y="tip", data=tips_data)

plt.title("Bill and Tips")

plt.show();

# %%
plt.figure(figsize=(12, 8))

sns.swarmplot(x="size", y="tip", data=tips_data)
plt.title("Bill and Tips")

plt.show();
# Out:
# C:\Users\natha\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:1296: UserWarning: 10.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(12, 8))

sns.swarmplot(x="size", y="total_bill", hue="above average", data=tips_data)

plt.title("Bill and Tips")

plt.show();

# %%
plt.figure(figsize=(12, 8))

sns.swarmplot(x="size", y="total_bill", hue="above average", data = tips_data, dodge=True)

plt.title("Bill and Tips")

plt.show();
# Out:
# C:\Users\natha\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:1296: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
