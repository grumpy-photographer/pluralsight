# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
auto_data = pd.read_csv("./datasets/automobile_data.csv", na_values="?")

auto_data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
auto_data.shape
# Out:
# (205, 26)

# %%
auto_data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
auto_data.dropna(inplace=True)
auto_data.shape
# Out:
# (159, 26)

# %%
# auto_data.to_csv('./datasets/automobile_data_processed.csv', index=False)

# %%
plt.figure(figsize=(12, 8))

sns.displot(auto_data["price"], color="red")

plt.title("Automobile Data")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.displot(auto_data["price"], color="red", bins=20)

plt.title("Automobile Data")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.kdeplot(auto_data["price"], color="red")

plt.title("Automobile Data")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.displot(auto_data["price"], color="red", rug=True)

plt.title("Automobile Data")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.rugplot(auto_data["price"], height=0.5, color="blue")

plt.title("Automobile Data")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.kdeplot(auto_data["price"], shade=True, color="blue")

plt.title("Automobile Data")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x="horsepower", y="price", data=auto_data, s=120)

plt.title("Automobile Data")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(
    x="horsepower", y="price", data=auto_data, hue="num-of-cylinders", s=120
)

plt.title("Automobile Data")

plt.show()

# %%
sns.regplot(x="horsepower", y="price", data=auto_data)
plt.show()

# %%
sns.regplot(x="highway-mpg", y="price", data=auto_data)
plt.show()

# %%
sns.jointplot(x='horsepower', y='price', data=auto_data)
plt.show()

# %%
sns.jointplot(x="horsepower", y='price', data=auto_data, kind="reg")
plt.show()

# %%
sns.jointplot(x='horsepower', y='price', data=auto_data, kind='kde')
plt.show()

# %%
sns.jointplot(x="horsepower", y="price", data= auto_data, kind="hex")
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 6))
    
sns.kdeplot(auto_data['horsepower'], auto_data['price'], ax = ax)

sns.rugplot(auto_data['horsepower'], color="limegreen", ax=ax)
sns.rugplot(auto_data["price"], color="red", vertical=True, ax=ax)

plt.title("Auto Data")

plt.show()
# Out:
# C:\Users\natha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\natha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2112: FutureWarning: Using `vertical=True` to control the orientation of the plot  is deprecated. Instead, assign the data directly to `y`.
#   warnings.warn(msg, FutureWarning)
